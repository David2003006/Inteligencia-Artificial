# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df_titanic = pd.read_csv("Sets/train.csv")
df_titanic = df_titanic[['Survived','Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked']]

# %%
df_titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0           0       3    male  22.0      1      0        S
# 1           1       1  female  38.0      1      0        C
# 2           1       3  female  26.0      0      0        S
# 3           1       1  female  35.0      1      0        S
# 4           0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0        S
# 887         1       1  female  19.0      0      0        S
# 888         0       3  female   NaN      1      2        S
# 889         1       1    male  26.0      0      0        C
# 890         0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
df_titanic= pd.get_dummies(df_titanic, columns=['Sex', 'Embarked'])

# %%
df_titanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch  Sex_female  Sex_male  Embarked_C  \
# 0           0       3  22.0      1      0       False      True       False
# 1           1       1  38.0      1      0        True     False        True
# 2           1       3  26.0      0      0        True     False       False
# 3           1       1  35.0      1      0        True     False       False
# 4           0       3  35.0      0      0       False      True       False
# ..        ...     ...   ...    ...    ...         ...       ...         ...
# 886         0       2  27.0      0      0       False      True       False
# 887         1       1  19.0      0      0        True     False       False
# 888         0       3   NaN      1      2        True     False       False
# 889         1       1  26.0      0      0       False      True        True
# 890         0       3  32.0      0      0       False      True       False
#
#      Embarked_Q  Embarked_S
# 0         False        True
# 1         False       False
# 2         False        True
# 3         False        True
# 4         False        True
# ..          ...         ...
# 886       False        True
# 887       False        True
# 888       False        True
# 889       False       False
# 890        True       False
#
# [891 rows x 10 columns]

# %%
mean_age = df_titanic['Age'].mean()
df_titanic['Age'] =  df_titanic['Age'].fillna(mean_age)
df_titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Sex_female    0
# Sex_male      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report

x = df_titanic.drop(columns='Survived')
y= df_titanic['Survived']

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, Y_train)
y_predict = model.predict(X_test)

acurrancy = accuracy_score(Y_test, y_predict)
f1 = f1_score(Y_test, y_predict)

print(f"La presicion es de: {acurrancy}")
print(f"Mi F1 es de: {f1}")
# Out:
# La presicion es de: 0.8212290502793296
# Mi F1 es de: 0.7714285714285715

# %%
print("Reporte de presiciones", classification_report(Y_test, y_predict))
# Out:
# Reporte de presiciones               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       105
#            1       0.82      0.73      0.77        74
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.81      0.81       179
# weighted avg       0.82      0.82      0.82       179

# %%
def Survived_titanic(df):
    predecir = df.values
    y_predict = model.predict(predecir)
    return y_predict

# %%
def dataset_comvertido(df):
    df = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked']]
    df= pd.get_dummies(df, columns=['Sex', 'Embarked'])
    return df

# %%
df_test = pd.read_csv("Sets/test.csv")
id= df_test['PassengerId'].values
df_titanic_test = dataset_comvertido(df_test)
prediciones_supervivencia = Survived_titanic(df_titanic_test)

df_output = pd.DataFrame({
    'id': id,
    'Survived': prediciones_supervivencia
})

df_output.to_csv("Sets/predicion.csv", index=False)
print("Archivo correctamente creado")
# Out:
# Archivo correctamente creado
# C:\Users\Lenovo 1\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
